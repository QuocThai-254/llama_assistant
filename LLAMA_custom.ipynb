# %%
# !pip install autotrain-advanced
# !pip install huggingface_hub

# %%
# !autotrain setup --update-torch
# Out:
# INFO     | 2024-04-06 09:58:21 | autotrain.cli.run_setup:run:43 - Installing latest xformers
# INFO     | 2024-04-06 09:58:22 | autotrain.cli.run_setup:run:45 - Successfully installed latest xformers
# INFO     | 2024-04-06 09:58:22 | autotrain.cli.run_setup:run:51 - Installing latest PyTorch
# INFO     | 2024-04-06 09:58:31 | autotrain.cli.run_setup:run:53 - Successfully installed latest PyTorch

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !autotrain llm --train --project-name llama-custom --model abhishek/llama-2-7b-hf-small-shards \
--data-path timdettmers/openassistant-guanaco --use-peft --lr 2e-4 --train-batch-size 2 --epochs 3 --trainer sft \
--quantization int4 --model_max_length 2048 --push-to-hub --token my-token \
--repo-id ChrisNguyen05/llama-custom --block-size 2048 > training.log &
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `0`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py:31: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# Repo card metadata block was not found. Setting CardData to empty.

# %%
# !autotrain llm --train --project-name llam-model-custom-data --model abhishek/llama-2-7b-hf-small-shards \
--data-path timdettmers/openassistant-guanaco --use-peft --lr 2e-4 --train-batch-size 2 --epochs 3 --trainer sft \
--model_max_length 2048 --push-to-hub --token my-token \
--repo-id ChrisNguyen05/llam-model-custom-data --block-size 2048

# %%
# !autotrain llm --train --project-name llam-model-custom-data --model TinyPixel/Llama-2-7B-bf16-sharded \
--data-path timdettmers/openassistant-guanaco --use-peft --lr 2e-4 --train-batch-size 2 --epochs 3 \
--trainer sft --model_max_length 2048 --push-to-hub --token my-token \
--repo-id ChrisNguyen05/llam-model-custom-data
